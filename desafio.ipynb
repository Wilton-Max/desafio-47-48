# %% [markdown]
# TABELA DE INVESTIMENTOS EM TV, RADIO E JORNAIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
tabela = pd.read_csv("advertising.csv", sep=",")
print(tabela)
# Out:
#         TV  Radio  Jornal  Vendas
# 0    230.1   37.8    69.2    22.1
# 1     44.5   39.3    45.1    10.4
# 2     17.2   45.9    69.3    12.0
# 3    151.5   41.3    58.5    16.5
# 4    180.8   10.8    58.4    17.9
# ..     ...    ...     ...     ...
# 195   38.2    3.7    13.8     7.6
# 196   94.2    4.9     8.1    14.0
# 197  177.0    9.3     6.4    14.8
# 198  283.6   42.0    66.2    25.5
# 199  232.1    8.6     8.7    18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# TOTAL INVESTIDO NA TV:

# %%
total_tv = tabela["TV"].sum()
print(total_tv)
# Out:
# 29408.5

# %% [markdown]
# TOTAL INVESTIDO EM RÁDIO:

# %%
total_radio = tabela["Radio"].sum()
print(total_radio)
# Out:
# 4652.800000000001

# %% [markdown]
# TOTAL INVESTIDO EM JORNAL:

# %%
total_jornal = tabela["Jornal"].sum()
print(total_jornal)
# Out:
# 6110.799999999999

# %% [markdown]
# TOTAL EM VENDAS:

# %%
total_vendas = tabela["Vendas"].sum()
print(total_vendas)
# Out:
# 3026.1000000000004

# %%
labels = ['TV', 'Radio', 'Jornal', 'Vendas']
totais = [total_tv, total_radio, total_jornal, total_vendas]

plt.pie(totais, labels=labels, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
# Out:
# (np.float64(-1.0999999578654474),
#  np.float64(1.0999999082622867),
#  np.float64(-1.0999997526495202),
#  np.float64(1.0999999882214058))
